# %%
run show_hdp.py
# Out:
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean

# %%
run test_hdp.py
# Out:
# random init mean

# %%
run test_hdp.py
# Out:
# random init mean

# %%
run test_hdp.py
# Out:
# random init mean

# %%
import show_hdp
# Out:
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3a17659e0a22> in <module>()
# ----> 1 import show_hdp
#
# /home/pawnty/Documents/hdp/show_hdp.py in <module>()
#     256
#     257 show_cosine()
# --> 258 show_grid()
#     259 show_comp()
#
# /home/pawnty/Documents/hdp/show_hdp.py in show_grid()
#     160     X = np.array([0, 0], dtype = 'float64')
#     161
# --> 162     for i in range(D):
#     163         #print i
#     164         cops = [gen_grid_data(batch_size), gen_grid_data(batch_size),
#
# NameError: global name 'D' is not defined
# random init mean
# random init mean

# %%
reload(show_hdp)
# Out:
# <module 'show_hdp' from 'show_hdp.py'>

# %%
show_hdp.gen_grid_dataset('/home/pawnty/tmp/data', 100, 200)

# %%
reload(show_hdp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-92fc499eab81> in <module>()
# ----> 1 reload(show_hdp)
#
# /home/pawnty/Documents/hdp/show_hdp.py in <module>()
#     299     plot(plt.subplot(224), hdp, X, Y, 'HDP', lim, 'm')
#     300     plt.show()
# --> 301 show_file_grid()
#     302 #show_cosine()
#     303 #show_grid()
#
# /home/pawnty/Documents/hdp/show_hdp.py in show_file_grid()
#     257
#     258 def show_file_grid():
# --> 259     np.random.seed(random_seed)
#     260     T = 20
#     261     K = 10
#
# NameError: global name 'random_seed' is not defined

# %%
run show_hdp.py
# Out:
# random init mean

# %%
run show_hdp.py
# Out:
# random init mean
# random init mean

# %%
run test_hdp.py
# Out:
# random init mean

# %%
run test_hdp.py
# Out:
# random init mean

# %%
run show_hdp.py
# Out:
# random init mean
# random init mean

# %%
run test_hdp.py
# Out:
# random init mean

# %%
run show_hdp.py
# Out:
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
# random init mean
